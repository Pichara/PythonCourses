# %%
print("Salve")
print("Bora aprender python")
#isso é um comentario
print(7+3)
print(8/2)
print(8*8)
print(8**8)
print(77-80)
# Out:
# Salve
# Bora aprender python
# 10
# 4.0
# 64
# 16777216
# -3
